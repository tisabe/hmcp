# %% [markdown]
# ## Importing libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt

# %%
from mcutils import *

# %% [markdown]
# # Polynomial fit for $\Delta H (\tau) \text{ with } \tau << 1$

# %%
plotData = []
filepath = "sample-outputs/test_md_out.txt"    #Import data from MD simulation without MC
#filepath = "outputs/test_md_out.txt"
with open(filepath,'r') as inputfile:
        for line in inputfile:
            plotData.append(line.strip().split('\t'))
        for j in range(len(plotData)):
            plotData[j] = [float(plotData[j][i]) for i in range(len(plotData[0]))]
plotData = np.array(plotData)
x = plotData[10:,0]
y = plotData[10:,1]

# %%
tau_function = lambda t,a,b : a*t**b
fitParams = opt.curve_fit(tau_function, x, y)[0]
print(fitParams)
# Out:
# [645.48112835   2.10149513]

# %%
plt.plot(x, y, marker="x", lw=0,label="Data")
plt.plot(x, tau_function(x,fitParams[0],fitParams[1]), label="Fit: %3.1f * x**%1.1f"%tuple(fitParams))
plt.xlabel("tau")
plt.ylabel("Delta H")
plt.legend()
plt.show()

# %% [markdown]
# # Check if momenta in heat bath have a Gaussian distribution and the random values are uncorrelated

# %%
filepath = "sample-outputs/heatbath_test_out.txt"
#filepath = "outputs/heatbath_test_out.txt"
plotData = []
with open(filepath,'r') as inputfile:
        for line in inputfile:
            plotData.append(line.strip().split('\t')) #Tab is used as seperator between values
        for j in range(len(plotData)): #Cast list items from string to float type
            plotData[j] = [float(plotData[j][i]) for i in range(len(plotData[0]))] # cast entries to float
plotData = np.array(plotData)

# %%
g = plotData[:,0]
h = plotData[:,1]

# %%
fit_fkt = lambda t, mu, a, b : a*np.exp(-(t-mu)**2/b)

# %% [markdown]
# ## Check for Gaussian distribution

# %%
num_bins = 50
histo = np.histogram(g, num_bins)
fit = opt.curve_fit(fit_fkt, (histo[1][:-1]+histo[1][1:])/2, histo[0])[0]
plt.hist(g, num_bins)
plt.plot((histo[1][:-1]+histo[1][1:])/2, fit_fkt((histo[1][:-1]+histo[1][1:])/2, fit[0], fit[1], fit[2]))
plt.xlabel("bins")
plt.ylabel("# of values per bin")
plt.show()

# %% [markdown]
# ## Check that autocorrelation $\approx$ 0

# %%
autocorr = calc_autocorr(g,500)
plt.plot(autocorr[1:])
plt.axhline(np.mean(autocorr))
plt.show()

# %% [markdown]
# ## Check for Gaussian distribution

# %%
num_bins = 50
histo = np.histogram(h, num_bins)
fit = opt.curve_fit(fit_fkt, (histo[1][:-1]+histo[1][1:])/2, histo[0])[0]
plt.hist(h, num_bins)
plt.plot((histo[1][:-1]+histo[1][1:])/2, fit_fkt((histo[1][:-1]+histo[1][1:])/2, fit[0], fit[1], fit[2]))
plt.xlabel("bins")
plt.ylabel("# of values per bin")
plt.show()

# %% [markdown]
# ## Check that autocorrelation $\approx$ 0

# %%
autocorr = calc_autocorr(g,500)
plt.plot(autocorr[1:])
plt.axhline(np.mean(autocorr))
plt.show()
